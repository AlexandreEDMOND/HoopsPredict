# %% [markdown]
# # Import

# %%
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
import urllib3
# Désactiver les avertissements de sécurité
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# # Prise en main

# %%
day = 29
month = 12
year = 2023


response = requests.get(f'https://www.basketball-reference.com/boxscores/?month={month}&day={day}&year={year}', verify=False)
# Vérifier si la requête a réussi
if response.status_code == 200:
    # Parser le contenu HTML avec BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extraire et afficher un contenu spécifique, par exemple les scores des matchs
    games = soup.find_all('div', class_='game_summary')
    
    for game in games:
        teams = game.find_all('a')

        team1 = teams[0].text
        team2 = teams[2].text
        
        scores = game.find_all('td', class_='right')
        score1 = scores[0].text
        score2 = scores[2].text
        
        print(f'{team1} {score1} - {team2} {score2}')
else:
    print('Failed to retrieve the page')
# Out:
# Sacramento 117 - Atlanta 110
# Toronto 118 - Boston 120
# Milwaukee 119 - Cleveland 111
# Oklahoma City 119 - Denver 93
# Philadelphia 131 - Houston 127
# Memphis 106 - LA Clippers 117
# New York 108 - Orlando 117
# Charlotte 119 - Phoenix 133
# San Antonio 128 - Portland 134
# Brooklyn 104 - Washington 110

# %% [markdown]
# # Stockage Data

# %%
class Match():

    def __init__(self, teamHome, teamAway, pointsHome, pointsAway):
        self.teamHome = teamHome
        self.teamAway = teamAway
        self.pointsHome = pointsHome
        self.pointsAway = pointsAway

        self.winnerHome = pointsHome > pointsAway
    
    def affichage_match(self):
        print(f"{self.teamHome} VS {self.teamAway} | {self.pointsHome}-{self.pointsAway} | Winner : {self.teamHome if self.winnerHome else self.teamAway}")

# %% [markdown]
# # Test Stockage

# %%
teams = []

for table in soup.find_all('div', class_='table_container'):
    for tbody in table.find_all('tbody'):
        for row in tbody:
            if row != "\n":
                teams_info = []
                for col in row:
                    if col != "\n":
                        teams_info.append(col.text.strip())
                teams.append(teams_info)
            # print(row)
            # team_info = ' '.join(col.text.strip() for col in row)
            # teams.append(team_info)
            # print(team_info)

print(teams)
# Out:
# [['Denver Nuggets*', '1', '0', '1.000', '—', '119.0', '107.0'], ['Phoenix Suns*', '1', '0', '1.000', '—', '108.0', '104.0'], ['Los Angeles Lakers*', '0', '1', '.000', '1.0', '107.0', '119.0'], ['Golden State Warriors', '0', '1', '.000', '1.0', '104.0', '108.0']]

# %%
list_matches = []

day = 24
month = 10
year = 2023


response = requests.get(f'https://www.basketball-reference.com/boxscores/?month={month}&day={day}&year={year}', verify=False)

# Vérifier si la requête a réussi
if response.status_code == 200:
    # Parser le contenu HTML avec BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    print(soup)
    
    # Extraire et afficher un contenu spécifique, par exemple les scores des matchs
    games = soup.find_all('div', class_='game_summary')
    
    for game in games:
        teams = game.find_all('a')

        team1 = teams[0].text
        team2 = teams[2].text
        
        scores = game.find_all('td', class_='right')
        score1 = scores[0].text
        score2 = scores[2].text
        
        list_matches.append(Match(team1, team2, score1, score2))
else:
    print('Failed to retrieve the page')


for match in list_matches:
    match.affichage_match()
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/bbr/deploy/www" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://cdn.ssref.net/req/202407231" rel="dns-prefetch"/>
# <script>
# /* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */
#   window.dataLayer = window.dataLayer ||[];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('consent','default',{
#         'ad_storage':'denied',
#         'analytics_storage':'denied',
#         'ad_user_data':'denied',
#         'ad_personalization':'denied',
#         'personalization_storage':'denied',
#         'functionality_storage':'granted',
#         'security_storage':'granted',
#         'wait_for_update': 500
#       });
#       gtag("set", "ads_data_redaction", true);
# </script>
# ...

# %% [markdown]
# # Scrapping

# %%
# Fonction pour récupérer et afficher les scores d'une date donnée
def get_scores(date, list_matches):
    response = requests.get(f'https://www.basketball-reference.com/boxscores/?month={date.month}&day={date.day}&year={date.year}', verify=False)

    nb_matchs = 0

    # Vérifier si la requête a réussi
    if response.status_code == 200:
        # Parser le contenu HTML avec BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extraire et afficher un contenu spécifique, par exemple les scores des matchs
        games = soup.find_all('div', class_='game_summary')
        
        for game in games:
            teams = game.find_all('a')

            team1 = teams[0].text
            team2 = teams[2].text
            
            scores = game.find_all('td', class_='right')
            score1 = scores[0].text
            score2 = scores[2].text

            list_matches.append(Match(team1, team2, score1, score2))

            nb_matchs += 1
        
        print(f"Nombre de match le {date.day} {date.month} : {nb_matchs}")
    else:
        print('Failed to retrieve the page')
    
    # Pour éviter le ban
    time.sleep(10 + random.uniform(-random.randint(1, 5)*random.random(), random.randint(1, 5)*random.random()) + random.random())

# %%
from datetime import datetime, timedelta

# Période de temps
start_date = datetime(2023, 10, 23)
# end_date = datetime(2024, 4, 15)
end_date = datetime(2023, 12, 29)

list_matches = []

# Boucle pour chaque jour de la période
current_date = start_date
while current_date <= end_date:
    get_scores(current_date, list_matches)
    current_date += timedelta(days=1)
# Out:
# Failed to retrieve the page
# Failed to retrieve the page
# Failed to retrieve the page
# Failed to retrieve the page
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#      11 current_date = start_date
#      12 while current_date <= end_date:
# ---> 13     get_scores(current_date, list_matches)
#      14     current_date += timedelta(days=1)
#
# Cell In[7], line 33, in get_scores(date, list_matches)
#      30 else:
#      31     print('Failed to retrieve the page')
# ---> 33 time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# # Affichage resultat

# %%
for match in list_matches:
    match.affichage_match()
print(len(list_matches))
# Out:
# LA Lakers VS Denver | 107-119 | Winner : Denver
# Phoenix VS Golden State | 108-104 | Winner : Phoenix
# Cleveland VS Brooklyn | 114-113 | Winner : Cleveland
# Oklahoma City VS Chicago | 124-104 | Winner : Oklahoma City
# Atlanta VS Charlotte | 110-116 | Winner : Charlotte
# Washington VS Indiana | 120-143 | Winner : Indiana
# Portland VS LA Clippers | 111-123 | Winner : LA Clippers
# New Orleans VS Memphis | 111-104 | Winner : New Orleans
# Detroit VS Miami | 102-103 | Winner : Miami
# Boston VS New York | 108-104 | Winner : Boston
# Houston VS Orlando | 86-116 | Winner : Houston
# Dallas VS San Antonio | 126-119 | Winner : Dallas
# Minnesota VS Toronto | 94-97 | Winner : Toronto
# Sacramento VS Utah | 130-114 | Winner : Sacramento
# Phoenix VS LA Lakers | 95-100 | Winner : Phoenix
# Philadelphia VS Milwaukee | 117-118 | Winner : Milwaukee
# New York VS Atlanta | 126-120 | Winner : New York
# Miami VS Boston | 111-119 | Winner : Boston
# ...
